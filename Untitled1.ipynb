# %%
#-*- coding: big5 -*-
#-*- coding: cp950 -*-
from bs4 import BeautifulSoup
import requests
from urllib.request import urlopen
from urllib.parse import urlparse
import datetime
import random
import re
import numpy as np
import pandas as pd


def get_dict(txt_sentence, txt_dict, num_dict):
    num = 0
    for stnce in txt_sentence:
        num = num + 1
        if(num>2 and num<len(txt_sentence)-2):
            #print(stnce)
            for sentence in stnce:
                stnce2 = re.sub(r"[0-9]+[, 、]*","",sentence)
                txt_dict[stnce2]=num_dict
                num_dict = num_dict + 1
    print(dict_sentence)
def include_dict(base, sample,dict_web):
    response=requests.get(sample)
    num_total_dict = len(dict_web)
    bs = BeautifulSoup(response.text, "html.parser")
    full_txt=bs.body.find_all('p');
    get_dict(full_txt,dict_sentence,0)
    for link in bs.find_all('a'):
        link_stg = link.get('href')
        if(len(link_stg)<=2 or len(link_stg)>=22):
            continue
        if (re.match(r"^[\s\S]+/+$",link_stg)):
            continue
        print(type(link_stg))
    
        full_link = base + link_stg
        print(r'internal link is',full_link)
        r = requests.get(full_link)
        if r.status_code == 404:
            print(r"hello",r.status_code, full_link)
        else:
            resp = requests.get(full_link)
            bs3 = BeautifulSoup(resp.text, "html.parser")
            full_txt=bs3.body.find_all('p');
            get_dict(full_txt, dict_sentence, num_total_dict)
    return 1
def simp_parse(base, sample,dict_web):
    resp = requests.get(sample)
    bs3 = BeautifulSoup(resp.text, "html.parser")
    full_txt=bs3.body.find_all('p');
    get_dict(full_txt, dict_sentence, len(dict_web))
    return 1
    
#html=urlopen('https://www.managertoday.com.tw/articles/view/51827')
#bs=BeautifulSoup(html.read(),'html.parser')
base = r"https://mingyanjiaju.org/"

#print(bs)

num_dict = 1
dict_sentence=dict()

# %%
simp_parse(base, r"https://mingyanjiaju.org/lizhimingyan/132438.html", dict_sentence)
simp_parse(base, r"https://mingyanjiaju.org//lizhimingyan/48360.html", dict_sentence)
simp_parse(base, r"https://mingyanjiaju.org/juzi/renshenggeyan/2012/0503/295.html", dict_sentence)
# Out:
# {'. 最困難之時，就是離成功不遠之日。 ——拿破崙': 0, '. 沒有朋友也沒有敵人的人，就是凡夫俗子。 ——拉法特': 1, '. 對眾人一視同仁，對少數人推心置腹，對任何人不要虧負。 ——莎士比亞': 2, '. 在各種孤獨中間，人最怕精神上的孤獨。 ——巴爾扎克': 3, '. 單獨一個人可能滅亡的地方，兩個人在一起可能得救。 ——巴爾扎克': 4, '. 真正的友情，是一株成長緩慢的植物。 ——華盛頓': 5, '. 親善產生幸福，文明帶來和諧。 ——雨 果': 6, '. 孩子還小時，給他們深根;等他們長大了，給他們翅膀。 ——印度諺語': 7, '. 你知道用什麼方法一定可以使你的孩子成為不幸的人嗎?這個方法就是對他百依百順。 ——盧 梭': 8, '. 有小孩的父母，即使對家畜等，也不可使用粗野的語言。 ——木村久一': 9, '. 教育之於心靈，猶雕刻之於大理石。 ——愛迪生': 10, '. 教育的目的，是替年輕人的終生自修作準備。 —— R.M.H.': 11, '. 母親是英勇無畏的，當事情涉及到她所誕生的和她所熱愛的生命的時候。 ——高爾基': 12, '. 上帝不能處處都在，於是他便創造了母親。 ——諺 語': 13, '. 母愛是世間最偉大的力量。 ——米 爾': 14, '. 對雙親來說，親職教育首先是自我教育。 ——克魯普斯卡婭': 15, '. 創造人的是自然界，啟迪和教育人的卻是社會。 ——別林斯基': 16, '. 培養人，就是培養他對前途的希望。 ——馬
# ...

# %%
simp_parse(base, r"https://mingyanjiaju.org/juzi/renshenggeyan/2010/0228/218.html", dict_sentence)
simp_parse(base, r"https://mingyanjiaju.org/juzi/jingdianduanju/2012/1114/335.html", dict_sentence)
simp_parse(base, r"https://mingyanjiaju.org/juzi/jingdianduanju/2012/0530/301.html", dict_sentence)
simp_parse(base, r"https://mingyanjiaju.org/hchj/118556.html", dict_sentence)
# Out:
# {'. 最困難之時，就是離成功不遠之日。 ——拿破崙': 0, '. 沒有朋友也沒有敵人的人，就是凡夫俗子。 ——拉法特': 1, '. 對眾人一視同仁，對少數人推心置腹，對任何人不要虧負。 ——莎士比亞': 2, '. 在各種孤獨中間，人最怕精神上的孤獨。 ——巴爾扎克': 3, '. 單獨一個人可能滅亡的地方，兩個人在一起可能得救。 ——巴爾扎克': 4, '. 真正的友情，是一株成長緩慢的植物。 ——華盛頓': 5, '. 親善產生幸福，文明帶來和諧。 ——雨 果': 6, '. 孩子還小時，給他們深根;等他們長大了，給他們翅膀。 ——印度諺語': 7, '. 你知道用什麼方法一定可以使你的孩子成為不幸的人嗎?這個方法就是對他百依百順。 ——盧 梭': 8, '. 有小孩的父母，即使對家畜等，也不可使用粗野的語言。 ——木村久一': 9, '. 教育之於心靈，猶雕刻之於大理石。 ——愛迪生': 10, '. 教育的目的，是替年輕人的終生自修作準備。 —— R.M.H.': 11, '. 母親是英勇無畏的，當事情涉及到她所誕生的和她所熱愛的生命的時候。 ——高爾基': 12, '. 上帝不能處處都在，於是他便創造了母親。 ——諺 語': 13, '. 母愛是世間最偉大的力量。 ——米 爾': 14, '. 對雙親來說，親職教育首先是自我教育。 ——克魯普斯卡婭': 15, '. 創造人的是自然界，啟迪和教育人的卻是社會。 ——別林斯基': 16, '. 培養人，就是培養他對前途的希望。 ——馬卡連柯': 17, '. 摯友如異體同心。 ——亞里士多德': 18, '. 世間最美好的東西，莫過於有幾個頭腦和心地都很正直的嚴正的朋友。 ——愛因斯坦': 19, '. 和你一同笑過的人，你可能把他忘掉;但是和你一同哭過的人，你卻永遠不忘。 ——紀伯倫': 20, '. 友誼是一種溫靜與沉著的愛，為理智所引導，習慣所結成，從長久的認識與共同的契合而產生，沒有嫉妒，也沒有恐懼。 ——荷 麥': 21, '. 友誼永遠是一個甜柔的責任，從來不是一種機會。 ——紀伯倫': 22, '. 真友誼象磷火——在你周圍最黑暗的時刻顯得最亮。 —— D.M.': 23, '. 如果人生的途程上沒有障礙，人還有什麼可做的呢。 ——俾斯麥': 24, '. 凡事在成熟之前，都是有苦味的
# ...

# %%
simp_parse(base, r"https://mingyanjiaju.org/juzi/jingdianduanju/2012/0218/274.html", dict_sentence)
simp_parse(base, r"https://mingyanjiaju.org/juzi/jingdianduanju/2012/0430/293.html", dict_sentence)
simp_parse(base, r"https://mingyanjiaju.org/juzi/jingdianduanju/2016/1019/1166.html", dict_sentence)
simp_parse(base, r"https://mingyanjiaju.org/juzi/renshenggeyan/2012/0316/284.html", dict_sentence)

# %%
import pandas as pd
len(dict_sentence)
df = pd.DataFrame(list(dict_sentence.items()),columns = ['sentence','value']) 
df.to_csv('test.csv')
