# %%
import requests
from bs4 import BeautifulSoup
from scrp_mod import Contents
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-eb54627e7970> in <module>
#       1 import requests
#       2 from bs4 import BeautifulSoup
# ----> 3 from scrp_mod import Contents
#
# ImportError: cannot import name 'Contents' from 'scrp_mod' (/Users/rubylintu/Desktop/trade/scrp_mod.py)

# %%
url = 'https://www.brookings.edu/blog/future-development/2018/01/26/delivering-inclusive-urban-access-3-uncomfortable-truths/'
content = Content.scrapeBrookings(url)
print('Title: {}'.format(content.title))
print('URL: {}\n'.format(content.url))
print(content.body)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-dbf3dbd84f23> in <module>
#       1 url = 'https://www.brookings.edu/blog/future-development/2018/01/26/delivering-inclusive-urban-access-3-uncomfortable-truths/'
# ----> 2 content = Content.scrapeBrookings(url)
#       3 print('Title: {}'.format(content.title))
#       4 print('URL: {}\n'.format(content.url))
#       5 print(content.body)
#
# ~/Desktop/trade/scrp_mod.py in scrapeBrookings(url)
#      29
#      30     def scrapeBrookings(url):
# ---> 31         bs = getPage(url)
#      32         title = bs.find('h1').text
#      33         body = bs.find('div', {'class', 'post-body'}).text
#
# NameError: name 'getPage' is not defined
