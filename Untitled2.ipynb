# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-1ca9e503f114> in <module>
#       1 search = str('covid19')
#       2 param='台郡'
# ----> 3 bing.text(param) #For Text Scraping.
#       4
#       5 bing.scrape(search).image() #For Image Scraping.
#
# <ipython-input-14-338f0b0cb211> in text(param)
#      14
#      15         results = soupt.find("ol", {"id":"b_results"})
# ---> 16         lists = results.findAll("li", {"class":"b_algo"})
#      17         file = open("./"+ self.getDir() + "/" + self.getSearch() +".txt", 'w')
#      18         file.close()
#
# AttributeError: 'NoneType' object has no attribute 'findAll'
